# %%
print("Shape:", df_long.shape)

duplicate_count = df_long.duplicated(
    subset=["location", "sku", "month"]
).sum()
print("Duplicates by location + sku + month:", duplicate_count)

print("\nMissing values:")
print(df_long.isna().sum())
# Out:
# Shape: (9336, 15)
# Duplicates by location + sku + month: 0
#
# Missing values:
# location                0
# sku                     0
# date_introduced         0
# last_release_date       0
# month                   0
# ABC_group               0
# outflow                 0
# extra_order             0
# production_order        0
# customer_demand         0
# turnover_ratio       5501
# ending_stock            0
# inflow                  0
# opening_stock           0
# balance_check        8357
# dtype: int64
